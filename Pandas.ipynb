# %% [markdown]
# # Series

# %%
import pandas as pd


series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({  1999: 48,
                            2000: 65,
                            2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39 ],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23],
                          })

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([ [74, 38, 39 ],
                             [34, 32, 32],
                             [23, 39, 23],
                           ], columns = [1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# # Read data

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('./web_scrapper_curso_data_eng/files/eluniversal_2020_04_13_articles.csv')

el_universal.tail()
# Out:
#                                                   body  \
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...
# 129  https://sanluis.eluniversal.com.mx/municipios/...
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...
# 131  https://www.eluniversal.com.mx//cartera/corona...
# 132  https://www.elgrafico.mx/la-roja/conductor-man...

# %% [markdown]
# # Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0      Tras 10 años de intentos, cuarentena ayuda a p...
# 1      Luis Fuentes se quedará seis meses más en América
# 2                                                    NaN
# 3      Cautiverio. Equipo estatal de esgrima entrena ...
# 4      Sanitizan 108 mil metros cuadrados del Centro ...
#                              ...
# 128                         El virus llegó para quedarse
# 129    Protección Civil en Soledad vigila que balnear...
# 130    Indigentes en la CDMX, invisibles ante la emer...
# 131    Coronavirus: 5 efectos devastadores que la pan...
# 132                                                  NaN
# Name: title, Length: 133, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...
# 1    https://www.eluniversal.com.mx//universal-depo...
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...
# 3    https://www.eluniversalqueretaro.mx/portada/ca...
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...
# ..                                                 ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...
# 129  https://sanluis.eluniversal.com.mx/municipios/...
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...
# 131  https://www.eluniversal.com.mx//cartera/corona...
# 132  https://www.elgrafico.mx/la-roja/conductor-man...
#
# [133 rows x 2 columns]

# %%
# Numpy like

#fila 10 a la 15
el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nAnte la insistencia de la ciudadanía de hace...
# 11  \nPachuca.- Al menos 11 casas incendiadas y un...
# 12  \n\n\n\n    googletag.cmd.push(function() {\n ...
# 13  \nElementos de la Secretaría de la Defensa Nac...
# 14  \n\n\n\n    googletag.cmd.push(function() {\n ...
#
#                                                 title  \
# 10  Sheinbaum llama a evitar reuniones y a no acud...
# 11  Se incendian 11 casas en Hidalgo y pobladores ...
# 12  UnADM: Carreras y maestrías en línea en la Uni...
# 13  Sedena asegura en Tijuana casi 245 mdp en fent...
# 14  Cuaderno de repaso para la cuarentena por coro...
#
#                                                   url
# 10  https://www.eluniversal.com.mx//metropoli/coro...
# 11  https://www.eluniversal.com.mx/estados/se-ince...
# 12  http://www.unionpuebla.mx/articulo/2020/03/17/...
# 13  https://www.eluniversal.com.mx//nacion/sedena-...
# 14  http://www.unionpuebla.mx/articulo/2020/03/18/...

# %%
el_universal.iloc[0]['title']
# Out:
# 'Tras 10 años de intentos, cuarentena ayuda a pandas a aparearse'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# Name: body, dtype: object

# %%
# loc varia de la sintaxis de rangos normal de python , 
# donde los rangos son inclusivos

el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
# [133 rows x 2 columns]

# %% [markdown]
# # Data wrangling

# %%
# 1. Añadir news_paper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url newspaper_uid
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...   eluniversal
# 1    https://www.eluniversal.com.mx//universal-depo...   eluniversal
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...   eluniversal
# 3    https://www.eluniversalqueretaro.mx/portada/ca...   eluniversal
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# ..                                                 ...           ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...   eluniversal
# 129  https://sanluis.eluniversal.com.mx/municipios/...   eluniversal
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# 131  https://www.eluniversal.com.mx//cartera/corona...   eluniversal
# 132  https://www.elgrafico.mx/la-roja/conductor-man...   eluniversal
#
# [133 rows x 4 columns]

# %%
# 2. Obtener el host

from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url newspaper_uid  \
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...   eluniversal
# 1    https://www.eluniversal.com.mx//universal-depo...   eluniversal
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...   eluniversal
# 3    https://www.eluniversalqueretaro.mx/portada/ca...   eluniversal
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# ..                                                 ...           ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...   eluniversal
# 129  https://sanluis.eluniversal.com.mx/municipios/...   eluniversal
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# 131  https://www.eluniversal.com.mx//cartera/corona...   eluniversal
# 132  https://www.elgrafico.mx/la-roja/conductor-man...   eluniversal
#
#                             host
# 0         www.eluniversal.com.mx
# 1         www.eluniversal.com.mx
# 2                 www.viveusa.mx
# 3    www.eluniversalqueretaro.mx
# 4         www.eluniversal.com.mx
# ..                           ...
# 128       www.eluniversal.com.mx
# 129   sanluis.eluniversal.com.mx
# 130       www.eluniversal.com.mx
# 131       www.eluniversal.com.mx
# 132             www.elgrafico.mx
#
# [133 rows x 5 columns]

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         79
# www.viveusa.mx                 13
# de10.com.mx                     6
# www.eluniversalqueretaro.mx     5
# www.elgrafico.mx                5
#                                ..
# www.unionedomex.mx              3
# www.unionyucatan.mx             2
# eluniversal.com.mx              1
# www.clubeluniversal.mx          1
# www.unioncdmx.mx                1
# Name: host, Length: 15, dtype: int64

# %% [markdown]
# # Missing data

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

""" 
es una serie booleana con true en donde faltan 
datos y false donde No
"""
# missing_titles_mask # 

# al hacer esta seleccion retorna todos los valores donde falten datos
print(el_universal[missing_titles_mask]['url'][2])


missing_titles = (el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(lambda title:    title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                )

missing_titles
# Out:
# https://www.viveusa.mx/showbiz/khloe-kardashian-remarca-sus-curvas-con-traje-de-bano-azul
#                                         missing_titles
# 2    khloe kardashian remarca sus curvas con traje ...
# 5    cae banda del cjng en edomex rescatan secuestr...
# 7    ella es hailie la hermosa influencer e hija de...
# 15   el festival burning man sera totalmente virtua...
# 19   visita los geiseres del parque de yellowstone ...
# ..                                                 ...
# 106  surge lady casas rompe cuarentena y explota co...
# 108  coronacasco asi piden respetar la cuarentena p...
# 120  las vegas la capital del juego convertida en u...
# 126  hay 296 muertes por coronavirus en mexico gate...
# 132  conductor maneja herido de bala hacia el hospi...
#
# [25 rows x 1 columns]

# %% [markdown]
# # Additional cleanup

# %%
# 4. añadir IDs
import hashlib

# El axis 1 significa filas
# El axis 0 significa columnas

# No usar hashlib.md5 para criptografia tiene problemas criptograficos

# el id lo genramos de transformar el url

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())) , axis = 1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )
el_universal['uid'] = uids

# inplace=True quiere que lo haga en el mismo dataframe en lugar de retornar otro
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# f8f1b2dc7b90b138bfa344381bc57783  \nHace 10 años venían intentándolo y todo indi...
# e47e9321d18661f4fdd9f2859d12af6a  \nEl América tiene pendiente definir la contin...
# b84aed035582af653f3b7919b80be328  \nLa conductora Khloé Kardashian compartió una...
# 63302077d30812fc3a6bc34970f83d17  \nLa Asociación Queretana de Esgrima utiliza l...
# 5e8a53c5ab7d840186a84353f8bfc883  \nDebido a la emergencia sanitaria por el coro...
# ...                                                                             ...
# b1eccfdde9c8d351f5adccb83082e8a8  \n\nUn buen amigo, profesor distinguido de his...
# c4cd9fb8dbc7595f30fb2e2bde78c09d  \nAutoridades de Protección Civil del municipi...
# 9a36f43aa4ec2569bf449eb3d0de0f4b  \n\nSentados en las banquetas en grupos de más...
# 08a97dcd6bae0fbd08dabea0a7a7406a  \n\nGetty Images\n \nLa caída del precio de la...
# feba64f1983dc3e8a7969e1f3bc8f5d2  Dos hombres heridos viajaban en un coche hacia...
#
#                                                                               title  \
# uid
# f8f1b2dc7b90b138bfa344381bc57783  Tras 10 años de intentos, cuarentena ayuda a p...
# e47e9321d18661f4fdd9f2859d12af6a  Luis Fuentes se quedará seis meses más en América
# b84aed035582af653f3b7919b80be328                                                NaN
# 63302077d30812fc3a6bc34970f83d17  Cautiverio. Equipo estatal de esgrima entrena ...
# 5e8a53c5ab7d840186a84353f8bfc883  Sanitizan 108 mil metros cuadrados del Centro ...
# ...                                                                             ...
# b1eccfdde9c8d351f5adccb83082e8a8                       El virus llegó para quedarse
# c4cd9fb8dbc7595f30fb2e2bde78c09d  Protección Civil en Soledad vigila que balnear...
# 9a36f43aa4ec2569bf449eb3d0de0f4b  Indigentes en la CDMX, invisibles ante la emer...
# 08a97dcd6bae0fbd08dabea0a7a7406a  Coronavirus: 5 efectos devastadores que la pan...
# feba64f1983dc3e8a7969e1f3bc8f5d2                                                NaN
#
#                                                                                 url  \
# uid
# f8f1b2dc7b90b138bfa344381bc57783  https://www.eluniversal.com.mx//ciencia-y-salu...
# e47e9321d18661f4fdd9f2859d12af6a  https://www.eluniversal.com.mx//universal-depo...
# b84aed035582af653f3b7919b80be328  https://www.viveusa.mx/showbiz/khloe-kardashia...
# 63302077d30812fc3a6bc34970f83d17  https://www.eluniversalqueretaro.mx/portada/ca...
# 5e8a53c5ab7d840186a84353f8bfc883  https://www.eluniversal.com.mx//metropoli/cdmx...
# ...                                                                             ...
# b1eccfdde9c8d351f5adccb83082e8a8  https://www.eluniversal.com.mx/opinion/juan-ra...
# c4cd9fb8dbc7595f30fb2e2bde78c09d  https://sanluis.eluniversal.com.mx/municipios/...
# 9a36f43aa4ec2569bf449eb3d0de0f4b  https://www.eluniversal.com.mx//metropoli/cdmx...
# 08a97dcd6bae0fbd08dabea0a7a7406a  https://www.eluniversal.com.mx//cartera/corona...
# feba64f1983dc3e8a7969e1f3bc8f5d2  https://www.elgrafico.mx/la-roja/conductor-man...
#
#                                  newspaper_uid                         host
# uid
# f8f1b2dc7b90b138bfa344381bc57783   eluniversal       www.eluniversal.com.mx
# e47e9321d18661f4fdd9f2859d12af6a   eluniversal       www.eluniversal.com.mx
# b84aed035582af653f3b7919b80be328   eluniversal               www.viveusa.mx
# 63302077d30812fc3a6bc34970f83d17   eluniversal  www.eluniversalqueretaro.mx
# 5e8a53c5ab7d840186a84353f8bfc883   eluniversal       www.eluniversal.com.mx
# ...                                        ...                          ...
# b1eccfdde9c8d351f5adccb83082e8a8   eluniversal       www.eluniversal.com.mx
# c4cd9fb8dbc7595f30fb2e2bde78c09d   eluniversal   sanluis.eluniversal.com.mx
# 9a36f43aa4ec2569bf449eb3d0de0f4b   eluniversal       www.eluniversal.com.mx
# 08a97dcd6bae0fbd08dabea0a7a7406a   eluniversal       www.eluniversal.com.mx
# feba64f1983dc3e8a7969e1f3bc8f5d2   eluniversal             www.elgrafico.mx
#
# [133 rows x 5 columns]

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''), letters)))
                     .apply(lambda letters_list: ''.join(letters_list))
                )
stripped_body
# Out:
# uid
# f8f1b2dc7b90b138bfa344381bc57783    Hace 10 años venían intentándolo y todo indica...
# e47e9321d18661f4fdd9f2859d12af6a    El América tiene pendiente definir la continui...
# b84aed035582af653f3b7919b80be328    La conductora Khloé Kardashian compartió una a...
# 63302077d30812fc3a6bc34970f83d17    La Asociación Queretana de Esgrima utiliza las...
# 5e8a53c5ab7d840186a84353f8bfc883    Debido a la emergencia sanitaria por el corona...
#                                                           ...
# b1eccfdde9c8d351f5adccb83082e8a8    Un buen amigo, profesor distinguido de histori...
# c4cd9fb8dbc7595f30fb2e2bde78c09d    Autoridades de Protección Civil del municipio ...
# 9a36f43aa4ec2569bf449eb3d0de0f4b    Sentados en las banquetas en grupos de más de ...
# 08a97dcd6bae0fbd08dabea0a7a7406a    Getty Images La caída del precio de las materi...
# feba64f1983dc3e8a7969e1f3bc8f5d2    Dos hombres heridos viajaban en un coche hacia...
# Length: 133, dtype: object
