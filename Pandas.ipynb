# %% [markdown]
# # Series

# %%
import pandas as pd


series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({  1999: 48,
                            2000: 65,
                            2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39 ],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23],
                          })

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([ [74, 38, 39 ],
                             [34, 32, 32],
                             [23, 39, 23],
                           ], columns = [1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# # Read data

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('./web_scrapper_curso_data_eng/files/eluniversal_2020_04_13_articles.csv')

el_universal.tail()
# Out:
#                                                   body  \
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...
# 129  https://sanluis.eluniversal.com.mx/municipios/...
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...
# 131  https://www.eluniversal.com.mx//cartera/corona...
# 132  https://www.elgrafico.mx/la-roja/conductor-man...

# %% [markdown]
# # Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0      Tras 10 años de intentos, cuarentena ayuda a p...
# 1      Luis Fuentes se quedará seis meses más en América
# 2                                                    NaN
# 3      Cautiverio. Equipo estatal de esgrima entrena ...
# 4      Sanitizan 108 mil metros cuadrados del Centro ...
#                              ...
# 128                         El virus llegó para quedarse
# 129    Protección Civil en Soledad vigila que balnear...
# 130    Indigentes en la CDMX, invisibles ante la emer...
# 131    Coronavirus: 5 efectos devastadores que la pan...
# 132                                                  NaN
# Name: title, Length: 133, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...
# 1    https://www.eluniversal.com.mx//universal-depo...
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...
# 3    https://www.eluniversalqueretaro.mx/portada/ca...
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...
# ..                                                 ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...
# 129  https://sanluis.eluniversal.com.mx/municipios/...
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...
# 131  https://www.eluniversal.com.mx//cartera/corona...
# 132  https://www.elgrafico.mx/la-roja/conductor-man...
#
# [133 rows x 2 columns]

# %%
# Numpy like

#fila 10 a la 15
el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nAnte la insistencia de la ciudadanía de hace...
# 11  \nPachuca.- Al menos 11 casas incendiadas y un...
# 12  \n\n\n\n    googletag.cmd.push(function() {\n ...
# 13  \nElementos de la Secretaría de la Defensa Nac...
# 14  \n\n\n\n    googletag.cmd.push(function() {\n ...
#
#                                                 title  \
# 10  Sheinbaum llama a evitar reuniones y a no acud...
# 11  Se incendian 11 casas en Hidalgo y pobladores ...
# 12  UnADM: Carreras y maestrías en línea en la Uni...
# 13  Sedena asegura en Tijuana casi 245 mdp en fent...
# 14  Cuaderno de repaso para la cuarentena por coro...
#
#                                                   url
# 10  https://www.eluniversal.com.mx//metropoli/coro...
# 11  https://www.eluniversal.com.mx/estados/se-ince...
# 12  http://www.unionpuebla.mx/articulo/2020/03/17/...
# 13  https://www.eluniversal.com.mx//nacion/sedena-...
# 14  http://www.unionpuebla.mx/articulo/2020/03/18/...

# %%
el_universal.iloc[0]['title']
# Out:
# 'Tras 10 años de intentos, cuarentena ayuda a pandas a aparearse'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# Name: body, dtype: object

# %%
# loc varia de la sintaxis de rangos normal de python , 
# donde los rangos son inclusivos

el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
# [133 rows x 2 columns]

# %% [markdown]
# # Data wrangling

# %%
# 1. Añadir news_paper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url newspaper_uid
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...   eluniversal
# 1    https://www.eluniversal.com.mx//universal-depo...   eluniversal
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...   eluniversal
# 3    https://www.eluniversalqueretaro.mx/portada/ca...   eluniversal
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# ..                                                 ...           ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...   eluniversal
# 129  https://sanluis.eluniversal.com.mx/municipios/...   eluniversal
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# 131  https://www.eluniversal.com.mx//cartera/corona...   eluniversal
# 132  https://www.elgrafico.mx/la-roja/conductor-man...   eluniversal
#
# [133 rows x 4 columns]

# %%
# 2. Obtener el host

from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \nHace 10 años venían intentándolo y todo indi...
# 1    \nEl América tiene pendiente definir la contin...
# 2    \nLa conductora Khloé Kardashian compartió una...
# 3    \nLa Asociación Queretana de Esgrima utiliza l...
# 4    \nDebido a la emergencia sanitaria por el coro...
# ..                                                 ...
# 128  \n\nUn buen amigo, profesor distinguido de his...
# 129  \nAutoridades de Protección Civil del municipi...
# 130  \n\nSentados en las banquetas en grupos de más...
# 131  \n\nGetty Images\n \nLa caída del precio de la...
# 132  Dos hombres heridos viajaban en un coche hacia...
#
#                                                  title  \
# 0    Tras 10 años de intentos, cuarentena ayuda a p...
# 1    Luis Fuentes se quedará seis meses más en América
# 2                                                  NaN
# 3    Cautiverio. Equipo estatal de esgrima entrena ...
# 4    Sanitizan 108 mil metros cuadrados del Centro ...
# ..                                                 ...
# 128                       El virus llegó para quedarse
# 129  Protección Civil en Soledad vigila que balnear...
# 130  Indigentes en la CDMX, invisibles ante la emer...
# 131  Coronavirus: 5 efectos devastadores que la pan...
# 132                                                NaN
#
#                                                    url newspaper_uid  \
# 0    https://www.eluniversal.com.mx//ciencia-y-salu...   eluniversal
# 1    https://www.eluniversal.com.mx//universal-depo...   eluniversal
# 2    https://www.viveusa.mx/showbiz/khloe-kardashia...   eluniversal
# 3    https://www.eluniversalqueretaro.mx/portada/ca...   eluniversal
# 4    https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# ..                                                 ...           ...
# 128  https://www.eluniversal.com.mx/opinion/juan-ra...   eluniversal
# 129  https://sanluis.eluniversal.com.mx/municipios/...   eluniversal
# 130  https://www.eluniversal.com.mx//metropoli/cdmx...   eluniversal
# 131  https://www.eluniversal.com.mx//cartera/corona...   eluniversal
# 132  https://www.elgrafico.mx/la-roja/conductor-man...   eluniversal
#
#                             host
# 0         www.eluniversal.com.mx
# 1         www.eluniversal.com.mx
# 2                 www.viveusa.mx
# 3    www.eluniversalqueretaro.mx
# 4         www.eluniversal.com.mx
# ..                           ...
# 128       www.eluniversal.com.mx
# 129   sanluis.eluniversal.com.mx
# 130       www.eluniversal.com.mx
# 131       www.eluniversal.com.mx
# 132             www.elgrafico.mx
#
# [133 rows x 5 columns]

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         79
# www.viveusa.mx                 13
# de10.com.mx                     6
# www.eluniversalqueretaro.mx     5
# www.elgrafico.mx                5
#                                ..
# www.unionguanajuato.mx          3
# www.unionyucatan.mx             2
# eluniversal.com.mx              1
# www.unioncdmx.mx                1
# www.clubeluniversal.mx          1
# Name: host, Length: 15, dtype: int64

# %% [markdown]
# # Missing data
